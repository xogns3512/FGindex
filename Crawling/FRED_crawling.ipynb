# %%
# !pip install fredapi

# %%
import pandas as pd
from fredapi import Fred
import matplotlib.pyplot as plt

# %%
fred = Fred(api_key = "cbce36d870c6ba2aec94181328225d9f")
data = fred.get_series('SP500')

# %%
macro_list = [
    "CPIAUCSL","WPSFD49207","DPCCRC1M027SBEA","PCE"
    ,"XTEXVA01USM659S","XTIMVA01USM659S","A822RO1Q156NBEA","B006RO1Q156NBEA"
    ,"A191RO1Q156NBEA","A001RO1Q156NBEA"
    ,"CP","TCU"
    ,"UNRATE","GFDEGDQ188S"
    ,"DFF","DTB3","DTB6","DGS1","DGS2","DGS3","DGS5","DGS7"
    ,"DGS10","DGS20","DGS30"
    ,"DAAA","DBAA"
    ,"TEDRATE"
    ,"T3MFF","T6MFF","T1YFF","T5YFF","T10YFF"
    ,"T10Y2Y","T10Y3M"    
    ,"AAAFF","BAAFF"
    ,"AAA10Y","BAA10Y"
]

# %%
tmp.to_csv("tmp.csv")
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
#   """Entry point for launching an IPython kernel.

# %%
for i in macro_list:
    tmp = fred.get_series(i)
    tmp.to_csv("/workspace/FGindex/DATA/tmp/{}.csv".format(i))
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:3: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
CP = pd.read_csv("Macro/CP.csv", header=None)
TCU = pd.read_csv("Macro/TCU.csv", header=None)
UNRATE = pd.read_csv("Macro/UNRATE.csv", header=None)
TEDRATE = pd.read_csv("Macro/TEDRATE.csv", header=None)
T3MFF = pd.read_csv("Macro/T3MFF.csv", header=None)
T6MFF = pd.read_csv("Macro/T6MFF.csv", header=None)
T1YFF = pd.read_csv("Macro/T1YFF.csv", header=None)
T5YFF = pd.read_csv("Macro/T5YFF.csv", header=None)
T10YFF = pd.read_csv("Macro/T10YFF.csv", header=None)

# %%
plt.plot(TEDRATE[1])\

# %%
plt.plot(T3MFF[1])
plt.plot(T6MFF[1])

# %%
plt.plot(T1YFF[1])
plt.plot(T5YFF[1])
plt.plot(T10YFF[1])

# %%
#B1 서비스 종료 지표
# TEDrate = fred.get_series("TEDRATE") 

#B2
T3MFF = fred.get_series("T3MFF")
T6MFF = fred.get_series('T6MFF')

#B3
T1YFF = fred.get_series("T1YFF")
T5YFF = fred.get_series('T5YFF')

#B4
T10Y2Y = fred.get_series('T10Y2Y')
T10Y3M = fred.get_series('T10Y3M')

#B5
AAAFF = fred.get_series('AAAFF')
BAAFF = fred.get_series('BAAFF')

#B6
AAA10Y = fred.get_series('AAA10Y')
BAA10Y = fred.get_series('BAA10Y')

# %%
BAA10Y
# Out:
# 1986-01-02    2.34
# 1986-01-03    2.30
# 1986-01-06    2.29
# 1986-01-07    2.35
# 1986-01-08    2.21
#               ...
# 2022-10-03    2.29
# 2022-10-04    2.27
# 2022-10-05    2.22
# 2022-10-06    2.16
# 2022-10-07    2.17
# Length: 9592, dtype: float64

# %%
plt.plot(TEDrate)

# %%
plt.plot(TEDrate)

# %%
plt.plot(T3MFF)

# %%
plt.plot(T1YFF)
plt.plot(T5YFF)

# %%
plt.plot(T10Y2Y)
plt.plot(T10Y3M)

# %%
plt.plot(AAAFF)
plt.plot(BAAFF)

# %%
plt.plot(AAA10Y)
plt.plot(BAA10Y)
